# %% [markdown]
# # Convolutional Neural Network and Model Interpretation
#
# - Train a convolutional neural network
# - Visualize the last "feature" layer
# - Visualize filters in the first convolution layer
# - Visualize activation regions of the input image

# %% [markdown]
# ### Setup drive
#
# Run the following cell to mount your Drive onto Colab. Go to the given URL and once you login and copy and paste the authorization code, you should see "drive" pop up in the files tab on the left.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Click the little triangle next to "drive" and navigate to the "AI4All Chest X-Ray Project" folder. Hover over the folder and click the 3 dots that appear on the right. Select "copy path" and replace `PASTE PATH HERE` with the path to your folder.

# %%
cd "/content/drive/My Drive/AI4All Chest X-Ray Project"
# Out:
# /content/drive/.shortcut-targets-by-id/1iJKbtzLay6C-5OfpVHhbe1nQeNGyhFWO/AI4All Chest X-Ray Project

# %%
cd "/content/drive/My Drive/UCSF AI4ALL 2020/AI4All Project/AI4All Chest X-Ray Project"
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/UCSF AI4ALL 2020/AI4All Project/AI4All Chest X-Ray Project'
# /content/drive/.shortcut-targets-by-id/1iJKbtzLay6C-5OfpVHhbe1nQeNGyhFWO/AI4All Chest X-Ray Project

# %%
cd "/content/drive/My Drive/AI4All Project/AI4All Chest X-Ray Project"
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/AI4All Project/AI4All Chest X-Ray Project'
# /content/drive/.shortcut-targets-by-id/1iJKbtzLay6C-5OfpVHhbe1nQeNGyhFWO/AI4All Chest X-Ray Project

# %% [markdown]
# ### Import necessary libraries

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

import torch
from torch import nn, optim
from torch.utils.data import DataLoader, random_split

import torchvision
from torchvision import datasets, models, transforms

from utils.datahelper import get_random_image
from utils.plotting import imshow_dataset, imshow_filters, plot_accuracy_curves, plot_loss_curve
from utils.modelhelper import calc_accuracy, get_train_validate_sizes, predict, train, visualize_cam, GradCAM

# %% [markdown]
# ### Setup paths

# %%
path_to_dataset = os.path.join('data')

path_to_images = os.path.join(path_to_dataset, 'images')

metadata = pd.read_csv(os.path.join(path_to_dataset, 'metadata_train.csv'))

# %% [markdown]
# ## Convolutional Neural Network (CNN)

# %% [markdown]
# ### Preprocess and split data
#
# The preprocessing and data splitting steps are the same as for the fully connected network
#
# **Preprocess data**
#
# Define preprocessing transforms

# %%
DATA_MEAN = 0.544
DATA_STD = 0.237

RESIZE_SIZE = 235
CROP_SIZE = 224 
IM_SIZE = CROP_SIZE

# preprocess transforms
data_transforms = transforms.Compose([
            transforms.Grayscale(),
            transforms.Resize(RESIZE_SIZE),
            transforms.CenterCrop(CROP_SIZE),
            transforms.ToTensor(),
            transforms.Normalize(mean=DATA_MEAN, std=DATA_STD)])

# %% [markdown]
# Sample data augmentation transforms (not used). Modify this code if you want to use augmentation!

# %%
# Framework for using data augmentation (not optimized)

DEGREE = 5
augmentation_transforms = [transforms.RandomAffine(degrees=DEGREE,
                                                   translate=((DEGREE / 100), (DEGREE/ 100)),
                                                   scale=(1 - (DEGREE / 100), 1 + (DEGREE / 100)),
                                                   shear=0),
                            transforms.RandomHorizontalFlip()]

data_transforms_augmented = transforms.Compose([
            transforms.Grayscale(),
            transforms.Resize(RESIZE_SIZE),
            *augmentation_transforms,
            transforms.CenterCrop(CROP_SIZE),
            transforms.ToTensor(),
            transforms.Normalize(mean=DATA_MEAN, std=DATA_STD)])

# %% [markdown]
# Create image dataset using defined transforms

# %%
dataset = datasets.ImageFolder(path_to_images, transform=data_transforms)

# %% [markdown]
# **Split the data into training and validation set**
#
# Randomly split dataset into training and validation set. Use DataLoaders define how to load data from training and validation datasets.

# %%
TRAIN_RATIO = 0.75
BATCH_SIZE = 64

# calculate training and validation set sizes
train_size, validate_size = get_train_validate_sizes(dataset, TRAIN_RATIO)

# split dataset into two training set and validation set
train_dataset, validate_dataset = random_split(dataset, [train_size, validate_size])

# create dataloaders
train_loader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=BATCH_SIZE)
validate_loader = DataLoader(dataset=validate_dataset, shuffle=False, batch_size=len(validate_dataset))

# %% [markdown]
# ### Ignore this
#
# Calculate convolution output / linear input size for the `nn.Sequential` container. There may be a better way to do this (without using `nn.Module`).

# %%
def calc_conv2d_dim(w, p=0, d=1, k=3, s=1):
    '''Calculate output dimension of a conv2d layer. Assumes input width=height 
    and kernels are square

    Args:
      w: input width/height (assumed equal)
      p: padding
      d: dilation
      k: kernel size (assumed equal)
      s: stride

    Returns: output dimension (width = height) 
    '''

    return math.floor((w + 2*p - d*(k-1) - 1) / s + 1)

# %%
def calc_maxpool2d_dim(w, p=0, d=1, k=2, s=2):
    '''Calculate output dimension of a maxpool2d layer. Assumes input width=height 
    and kernels are square

    Args:
      w: input width/height (assumed equal)
      p: padding
      d: dilation
      k: kernel size (assumed equal)
      s: stride

    Returns: output dimension (width = height) 
    '''
    return math.floor((w + 2*p - d*(k-1) - 1) / s + 1)

# %% [markdown]
# Calculate the convolution block output size.
#
# To calculate the input size for the first linear layer in the fully connected block: k x w x h
#
# k: number of kernels in the last conv layer
#
# w = h: convolution block output size

# %%
# order of conv2d and maxpool2d layers as a string
layers = 'cmcm'

current_size = IM_SIZE

# calculate convolution block output size
# modify if you need to parameterize layers individually
for l in layers:
    if l == 'c':
        current_size = calc_conv2d_dim(current_size, k=3)
    elif l == 'm':
        current_size = calc_maxpool2d_dim(current_size)

cnn_out_size = current_size
print(f'Convolution block output size: {cnn_out_size}')
# Out:
# Convolution block output size: 54

# %% [markdown]
# ### Setup and train CNN
#
# **Define CNN**
#
# The CNN network consists of a convolution section followed by a fully connected section. The convolutin section is a sequence of convolution (`nn.Conv2d`) layers followed up by activation (`nn.ReLu`) and max pooling (`nn.MaxPool2d`).
#
# The output from the convolution section is then flattened (`nn.Flatten`) for the fully connected section.
#
# As before, the fully connected layer is a sequence of linear (`nn.Linear`) layers followed by activation (`nn.ReLu`).
#
# We end the network with an output linear layer followed by log softmax (`nn.LogSoftmax`). This outputs the log probability (likelihood) for each class label.
#
# Read about convolution layers in PyTorch [here](https://pytorch.org/docs/master/nn.html#convolution-layers)

# %%
model = nn.Sequential(nn.Conv2d(1, 16, 3),
                      nn.ReLU(),
                      nn.MaxPool2d(2, 2),
                      nn.Conv2d(16, 16, 3),
                      nn.ReLU(),
                      nn.MaxPool2d(2, 2),
                      nn.Flatten(),
                      nn.Linear(16 * cnn_out_size * cnn_out_size, 16),
                      nn.ReLU(),
                      nn.Linear(16,  8),
                      nn.ReLU(),
                      nn.Linear(8, 2),
                      nn.LogSoftmax(dim=1))

print(model)
# Out:
# Sequential(
#   (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#   (4): ReLU()
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Flatten()
#   (7): Linear(in_features=46656, out_features=16, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=16, out_features=8, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=8, out_features=2, bias=True)
#   (12): LogSoftmax(dim=1)
# )

# %% [markdown]
# **Train CNN**
#
# Same function as for fully connected NN

# %%
train_accuracy_log, validate_accuracy_log, loss_log = train(model, train_loader, validate_loader, epoch_num=1)
# Out:
# [epoch 0 batch 0] Loss: 0.720 Train accuracy: 0.547 Val accuracy: 0.515
# [epoch 0 batch 1] Loss: 0.713 Train accuracy: 0.516 Val accuracy: 0.515
# [epoch 0 batch 2] Loss: 0.696 Train accuracy: 0.547 Val accuracy: 0.515
# [epoch 0 batch 3] Loss: 0.762 Train accuracy: 0.484 Val accuracy: 0.515
# [epoch 0 batch 4] Loss: 0.791 Train accuracy: 0.438 Val accuracy: 0.515
# [epoch 0 batch 5] Loss: 0.662 Train accuracy: 0.484 Val accuracy: 0.520
# [epoch 0 batch 6] Loss: 0.602 Train accuracy: 0.531 Val accuracy: 0.551
# [epoch 0 batch 7] Loss: 0.669 Train accuracy: 0.453 Val accuracy: 0.737
# [epoch 0 batch 8] Loss: 0.550 Train accuracy: 0.766 Val accuracy: 0.838
# [epoch 0 batch 9] Loss: 0.559 Train accuracy: 0.875 Val accuracy: 0.854
# Finished Training

# %%
plot_accuracy_curves(train_accuracy_log, validate_accuracy_log)

# %% [markdown]
# ## Model Interpretation
#
# This section walks through three approaches for model interpretation, or understanding how a neural network makes its decisions.
#
# Don't worry about the code in this section as it's a bit more complicated. We will focus on the visualizations and interpretations as we go through the section together.

# %% [markdown]
# ### Visualize features in fully connected layer
#
#
# We can visualize the feautures being learned in a fully connected layer by recording and plotting the layer activations for a given set of input images. The space of the features is also called the latent space. Here, we take a look at the last layer before the output layer.

# %%
def save_output_hook(module, input, output):
    '''Hook for saving module output to module'''
    setattr(module, '_output_hook', output)

# %%
def get_feature_outputs(model, test_loader, layer_num=-3, inputs_num=300):
  '''Get outputs for the feauture layer. Default feature layer is the fully 
  connected layer right before the output layer

  Args:
    model: neural network
    test_loader: DataLoader for test images
    layer_num: layer number for activation (e.g. relu) layer of the feature layer
    inputs_num: number of test inputs to run

  Returns: layer_outputs, actual_labels
  '''

  # register a hook to save the output
  output_handle = model[layer_num].register_forward_hook(save_output_hook)

  layer_outputs = []
  labels = []

  for i in range(inputs_num):

    # get the next image
    input, label = next(iter(test_loader))

    # forward pass with an input image
    output = model(input)

    # get the activation value
    layer_output = model[layer_num]._output_hook.data
    layer_output = layer_output[0].numpy()

    layer_outputs.append(layer_output)
    labels.append(label.item())

  # remove hook
  output_handle.remove()

  layer_outputs = np.array(layer_outputs)

  return layer_outputs, labels

# %%
# define test data loader
dataset_test = datasets.ImageFolder(path_to_images, transform=data_transforms)
test_loader = DataLoader(dataset=dataset_test, shuffle=True, batch_size=1)

# %%
# get feature activations before training
activation_pretrain, labels_pretrain = get_feature_outputs(model, test_loader)

train_accuracy_log = []
validate_accuracy_log = []
loss_log = []

# get feature activations after training for one epoch
training_output = train(model, train_loader, validate_loader, epoch_num=1)

train_accuracy_log += training_output[0]
validate_accuracy_log += training_output[1]
loss_log += training_output[2]

activation_train1, labels_train1 = get_feature_outputs(model, test_loader)

# get feature activations after training for another 3 epochs
training_output = train(model, train_loader, validate_loader, epoch_num=3)

train_accuracy_log += training_output[0]
validate_accuracy_log += training_output[1]
loss_log += training_output[2]

activation_train2, labels_train2 = get_feature_outputs(model, test_loader)
# Out:
# [epoch 0 batch 0] Loss: 0.519 Train accuracy: 0.922 Val accuracy: 0.566
# [epoch 0 batch 1] Loss: 1.103 Train accuracy: 0.453 Val accuracy: 0.747
# [epoch 0 batch 2] Loss: 0.358 Train accuracy: 0.875 Val accuracy: 0.864
# [epoch 0 batch 3] Loss: 0.483 Train accuracy: 0.875 Val accuracy: 0.712
# [epoch 0 batch 4] Loss: 0.527 Train accuracy: 0.797 Val accuracy: 0.843
# [epoch 0 batch 5] Loss: 0.434 Train accuracy: 0.891 Val accuracy: 0.884
# [epoch 0 batch 6] Loss: 0.385 Train accuracy: 0.938 Val accuracy: 0.854
# [epoch 0 batch 7] Loss: 0.397 Train accuracy: 0.875 Val accuracy: 0.783
# [epoch 0 batch 8] Loss: 0.408 Train accuracy: 0.812 Val accuracy: 0.793
# [epoch 0 batch 9] Loss: 0.341 Train accuracy: 0.875 Val accuracy: 0.864
# Finished Training
# [epoch 0 batch 0] Loss: 0.306 Train accuracy: 0.938 Val accuracy: 0.490
# [epoch 0 batch 1] Loss: 0.805 Train accuracy: 0.531 Val accuracy: 0.843
# [epoch 0 batch 2] Loss: 0.402 Train accuracy: 0.828 Val accuracy: 0.763
# [epoch 0 batch 3] Loss: 0.367 Train accuracy: 0.844 Val accuracy: 0.662
# [epoch 0 batch 4] Loss: 0.641 Train accuracy: 0.562 Val accuracy: 0.677
# [epoch 0 batch 5] Loss: 0.560 Train accuracy: 0.688 Val accuracy: 0.778
# [epoch 0 batch 6] Loss: 0.415 Train accuracy: 0.750 Val accuracy: 0.864
# [epoch 0 batch 7] Loss: 0.365 Train accuracy: 0.844 Val accuracy: 0.874
# [epoch 0 batch 8] Loss: 0.327 Train accuracy: 0.922 Val accuracy: 0.783
# [epoch 0 batch 9] Loss: 0.340 Train accuracy: 0.875 Val accuracy: 0.758
# [epoch 1 batch 0] Loss: 0.366 Train accuracy: 0.859 Val accuracy: 0.803
# [epoch 1 batch 1] Loss: 0.459 Train accuracy: 0.828 Val accuracy: 0.864
# [epoch 1 batch 2] Loss: 0.379 Train accuracy: 0.844 Val accuracy: 0.899
# [epoch 1 batch 3] Loss: 0.315 Train accuracy: 0.891 Val accuracy: 0.884
# [epoch 1 batch 4] Loss: 0.263 Train accuracy: 0.938 Val accuracy: 0.813
# [epoch 1 batch 5] Loss: 0.364 Train accuracy: 0.812 Val accuracy: 0.803
# [epoch 1 batch 6] Loss: 0.393 Train accuracy: 0.797 Val accuracy: 0.813
# [epoch 1 batch 7] Loss: 0.303 Train accuracy: 0.859 Val accuracy: 0.864
# [epoch 1 batch 8] Loss: 0.289 Train accuracy: 0.906 Val accuracy: 0.879
# [epoch 1 batch 9] Loss: 0.180 Train accuracy: 0.938 Val accuracy: 0.899
# [epoch 2 batch 0] Loss: 0.259 Train accuracy: 0.922 Val accuracy: 0.884
# [epoch 2 batch 1] Loss: 0.122 Train accuracy: 1.000 Val accuracy: 0.843
# [epoch 2 batch 2] Loss: 0.318 Train accuracy: 0.875 Val accuracy: 0.838
# [epoch 2 batch 3] Loss: 0.314 Train accuracy: 0.828 Val accuracy: 0.884
# [epoch 2 batch 4] Loss: 0.266 Train accuracy: 0.875 Val accuracy: 0.904
# [epoch 2 batch 5] Loss: 0.345 Train accuracy: 0.859 Val accuracy: 0.904
# [epoch 2 batch 6] Loss: 0.164 Train accuracy: 0.938 Val accuracy: 0.869
# [epoch 2 batch 7] Loss: 0.220 Train accuracy: 0.891 Val accuracy: 0.859
# [epoch 2 batch 8] Loss: 0.225 Train accuracy: 0.922 Val accuracy: 0.859
# [epoch 2 batch 9] Loss: 0.616 Train accuracy: 0.750 Val accuracy: 0.869
# Finished Training

# %%
# plot training curves
plot_accuracy_curves(train_accuracy_log, validate_accuracy_log)
plot_loss_curve(loss_log)

# %%
from sklearn.manifold import TSNE

def plot_tsne(activations, labels, ax):
  '''Compute and plot tsne plot'''

  tsne = TSNE(n_components=2, perplexity=40, n_iter=5000)
  feature_tsne = tsne.fit_transform(activations)

  df_tsne = pd.DataFrame({
      'tsne_x': feature_tsne[:,0],
      'tsne_y': feature_tsne[:,1],
      'target_labels': labels})
  print(feature_tsne[:,0])
  print(feature_tsne[:,1])

  sns.scatterplot(x='tsne_x', y='tsne_y', hue='target_labels', data=df_tsne, legend='full', ax=ax)

# %%
# plot tsne plots
fig, ax = plt.subplots(1, 3, figsize=(15,5))
ax = ax.ravel()

plot_tsne(activation_pretrain, labels_pretrain, ax=ax[0])
ax[0].set_title('Pre-training')
plot_tsne(activation_train1, labels_train1, ax=ax[1])
ax[1].set_title('After 1 epoch')
plot_tsne(activation_train2, labels_train2, ax=ax[2])
ax[2].set_title('After 3 epochs')

plt.suptitle('FC feature TSNE visualization')
plt.show()
# Out:
# [ -3.3865526   -6.047681    -5.4972034  -12.272322    -6.9322186
#  -15.468838     0.8481515  -16.002022   -15.835889   -11.50787
#    2.8675673   11.809824     2.5313225   14.425317   -14.420151
#  -13.578572   -11.115002     7.162878    -1.4448745  -14.941499
#   -6.8131714   -6.896361    -9.617841    13.640353    11.082779
#   10.735074   -14.352187    -0.66856515  -0.77130055  13.095819
#    3.73508    -11.941772     4.30542    -12.193586    -1.4448745
#   -7.941752     8.766225     9.286111   -13.829491     6.9885716
#   1.6926286  -5.6956487   2.5001624  -4.689255    3.5085566   2.028978
#   1.8095168   2.640536   -5.8268905   2.0463285  -3.7334392   0.85562545
#  -5.4657607   0.09398784  1.8151776   2.237601    2.6257355   1.0714862
#  -6.738808    1.5151163  -1.9300088   2.7070289  -0.44738874 -0.70692176
#  -1.0396339  -5.8443766   1.6130776   2.832241    0.29558462  1.7867694
#  -2.2710493   3.7132154   2.0910065   2.5835202   1.6926296   1.3201952 ]

# %%
from sklearn.decomposition import PCA

def plot_pca(activations, labels, ax):
  '''Compute and plot PCA plot'''

  pca = PCA(n_components=2)
  feature_pca = pca.fit_transform(activations)

  df_pca = pd.DataFrame({
      'pca1': feature_pca[:,0],
      'pca2': feature_pca[:,1],
      'target_labels': labels})
  
  print(feature_pca[:,0])
  print(feature_pca[:,1])

  sns.scatterplot(x='pca1', y='pca2', hue='target_labels', data=df_pca, legend='full', ax=ax)

# %%
# plot pca plots
fig, ax = plt.subplots(1, 3, figsize=(15,5))
ax = ax.ravel()

plot_pca(activation_pretrain, labels_pretrain, ax=ax[0])
ax[0].set_title('Pre-training')
plot_pca(activation_train1, labels_train1, ax=ax[1])
ax[1].set_title('After 1 epoch')
plot_pca(activation_train2, labels_train2, ax=ax[2])
ax[2].set_title('After 3 epochs')

plt.suptitle('FC feature PCA visualization')
plt.show()
# Out:
# [ 0.18078695  0.3757391   0.55132365  1.358171    0.5169918   2.2950487
#  -0.38208398  2.0275178   2.0275178   1.1692572  -0.97727823 -1.4826288
#  -0.9447974  -1.4956951   1.6665852   1.7135704   1.1225893  -0.9999719
#  -0.71295136  1.8497326   0.78104854  0.7238476   0.93569344 -1.2792588
#  -1.2293116  -1.4264473   1.6374298  -0.5576248  -0.9314049  -1.1957226
#  -0.9598994   1.2152814  -1.0234747   1.4210476  -0.71295136  0.90012836
#  -1.4042479  -1.2385774   1.5104878  -1.0012178   0.64816403 -0.6814583
#  -0.15901     0.6936233  -0.1530269   0.76575434  0.0264588   1.1926274
#   1.1924464  -1.5948474  -1.6995307   1.0621133   1.4439901  -0.8576706
#  -1.6053799  -1.0012178  -0.32807642  1.095031   -1.2307858   1.1543329
#  -1.6420261  -1.4534578  -1.1486131   0.7710364  -1.0091246   1.4027503
#   0.37048498  0.6629218   0.6724222   1.1677183  -0.30233204  1.095031
#   1.792097    1.8497326  -1.0275404  -0.6772449  -1.4264473   0.819396
#  -1.3570656   1.1460865   0.6724222  -1.6534458  -0.53252345  0.9621839
#   1.4458946   0.78104854  0.59767646  0.18601654 -1.8800893  -1.2730268
#  -0.9049735   1.2478911  -0.8304634   1.0595725   0.813107    0.5912384
#   1.6610945  -1.6057477   1.250109    1.1012274  -1.2754595  -1.238624
#  -1.5185457   0.69417226 -1.2307858  -1.2601013   0.23922454  1.0771466
#  -1.7647035  -0.6948582  -0.8990373   0.5631919  -0.5576248   1.1815497
#  -1.243408    2.1701567   1.3255496  -0.9111882   0.7760749   1.8327991
#   1.1576548   0.59647983  1.9359256   0.06220661  1.2774104   1.2544115
#  -0.2679748   0.13474877 -0.34035978 -0.605159    0.04307552  2.137552
#   0.68773115 -0.07499222 -0.44355285  0.32739633 -0.51188666  0.6430183
#   0.73503274 -0.605159    0.10458573 -1.1450715  -0.6188864   0.52152383
#  -0.0781921  -0.32273167  0.3117789  -0.7803476   0.8353146  -0.04820996
#  -0.7803476  -0.897033    0.0620045  -0.50075656  0.10458573 -1.6236416
#   0.6166008  -0.13587782  0.69421333  1.1321263   0.12195107  0.50954
#  -0.40054542 -0.07864877 -1.2499737   0.17796804  0.57319474  1.1209017
#   1.1320196   0.6854047   1.2868209  -0.7918232   0.4941935   0.865642
#   0.7901123   0.44716397 -0.69402176 -0.02529738 -0.15149246 -0.3041765
#   0.41812503 -0.6094419  -0.5273157  -0.08878411  0.6030609  -1.2890882
#  -0.5460815  -0.01839825 -0.23361404  0.26114285  0.14424166  0.9234982
#  -1.7309433   0.18955831  0.6103993   0.08813646 -1.1567332  -0.765367
#   0.24856332  0.32392472 -0.9038544  -0.19860335  0.6006745   0.5489853
#  -1.514171   -0.66635877  0.00278398 -0.86465013  0.10130867 -0.2485883
#  -0.40054542 -0.34048823 -0.7803476  -0.03663997  0.86643976 -0.13884321
#  -0.521687    0.11751474 -0.55918944  0.25434625  0.6256182  -0.41615483
#  -0.28881216 -0.36703035 -0.42659077 -0.11221257 -0.47812432 -0.2769785
#  -1.0130345   0.07927822 -0.010824    0.59020734  0.70243895  0.9178561
#   0.04438786 -0.56279045  0.05118405  0.04846636  0.14909093 -0.15357588
#   1.1209016   0.9609415  -0.2679748  -0.86467    -0.40054542  0.067193  ]

# %% [markdown]
# ### Visualize CNN filters
#
# We can also visualize the filters being learned in the first convolution layer of a CNN

# %% [markdown]
# **Show filters for the CNN we just trained**

# %%
# get filters from the first convolution layer
filters = model[0].weight.data
imshow_filters(filters, single_channel=True)

# %% [markdown]
# **Show filters for a pre-trained model (AlexNet)**

# %%
# load pre-trained alexnet
alexnet = models.alexnet(pretrained=True)

# get first layer weights
filters = alexnet.features[0].weight.data
imshow_filters(filters)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %% [markdown]
# **Show filters for a pre-trained model (VGG16)**

# %%
# load vgg
vgg16 = models.vgg16(pretrained=True)

# get first layer weights
filters = vgg16.features[0].weight.data
imshow_filters(filters)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))

# %% [markdown]
# ### Class activation maps
#
# Class activation maps (CAMs) show which region of the image is being used (activated) to make the prediction.

# %%
def show_random_gradcam(model, target_layer, dataset):
  # get a random image
  im = get_random_image(dataset)
  im_batch = torch.stack([im])

  # run gradient class activation mapping
  gradcam = GradCAM(model, target_layer)
  mask, logit = gradcam(im_batch)
  heatmap, cam_result = visualize_cam(mask, im_batch)

  # show results
  fig, ax = plt.subplots(1,3)
  plt.gray()
  ax[0].imshow(np.squeeze(im))
  ax[1].imshow(transforms.ToPILImage()(heatmap))
  ax[2].imshow(transforms.ToPILImage()(cam_result))

# %%
# find the last convolution layer and set as target layer
target_layer = model._modules['3']

show_random_gradcam(model, target_layer, dataset)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
show_random_gradcam(model, target_layer, dataset)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
show_random_gradcam(model, target_layer, dataset)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
show_random_gradcam(model, target_layer, dataset)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
